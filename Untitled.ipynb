# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\User\\pythonTutorial'

# %%
ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: A84A-21E0
#
#  C:\Users\User\pythonTutorial 디렉터리
#
# 2020-06-27  오후 12:59    <DIR>          .
# 2020-06-27  오후 12:59    <DIR>          ..
# 2020-06-27  오후 12:57    <DIR>          .ipynb_checkpoints
# 2020-06-27  오후 12:59             1,154 Untitled.ipynb
#                1개 파일               1,154 바이트
#                3개 디렉터리  30,800,592,896 바이트 남음

# %%
# !ls
# Out:
# 'ls'은(는) 내부 또는 외부 명령, 실행할 수 있는 프로그램, 또는
# 배치 파일이 아닙니다.
